# %% [markdown]
# **Week-1: Practice Questions on Topics- Data Types, Control Structures, String Slicing, Functions, and Collections**

# %% [markdown]
# Q1: Create a Python program that asks the user to enter two integers. The program should then calculate and display the sum, difference, product, and division result of the two numbers. Make sure to include a check to handle division by zero gracefully.

# %% [markdown]
# Q2:Imagine you have a bank account in a Bahrain bank. You want to calculate your updated balance after some transactions.
#
#     First, take your current account balance as input.
#
#     Then, deposit 15.5 units into your account.
#
#     After that, withdraw 10.25 units.
#
#     Finally, display your new account balance in a clear and friendly way.
#
# Hint: Make your program user-friendly by formatting the final balance with two decimal places.

# %%
# Out:
# Enter current balance: 60
# Total balance: 65.25

# %% [markdown]
# Q3: Create a Python program that welcomes the user by their full name.
#
#     The program should first ask for the user's first name.
#
#     Then, it should prompt for their last name.
#
#     Finally, display a personalized greeting message that combines both the first and last name, making the user feel welcomed.
#
# Hint: Add a nice touch by including a friendly message like "Hello, [First Name] [Last Name]! Welcome to the world of Python!".

# %% [markdown]
# Q4:  Imagine you are building a voting eligibility checker for a community app in Bahrain.
#
#     Write a Python program that asks the user to enter their age.
#
#     Check if the entered age is 18 years or older, which is the legal voting age.
#
#     Display an appropriate message indicating whether the user is eligible to vote or not.
#
# Hint: Consider using a simple if-else structure for a clear and straightforward user experience.

# %% [markdown]
# Q5: Create a Python program that converts a floating-point number (entered as a string) into an integer.
#
#     Prompt the user to enter a number in decimal format (e.g., "25.75").
#
#     Convert this string into an integer.
#
#     Print the converted integer value.

# %% [markdown]
# Q6:  Create a Python program that takes a word as input from the user and slices it from the middle.
#
#     Prompt the user to enter a word.
#
#     Find the middle position of the word.
#
#     Slice the word into two halves, starting from the middle.
#
#     Display the sliced portions separately.
#
# Hint: Remember that if the word has an odd number of letters, the middle letter should be included in the second half.

# %% [markdown]
# Q7: Build a Python program that demonstrates the concept of memory addresses in Python.
#
#     Create two variables with the same value.
#
#     Print the memory addresses of both variables using the id() function.
#
#     Observe whether the addresses are the same or different.

# %% [markdown]
# Q8: Develop a Python program that categorizes a student's grade based on their score.
#
#     Prompt the user to enter the student's grade as a number.
#
#     Use the following grading criteria:
#
#         90 or above: Print 'A'
#
#         80 to 89: Print 'B'
#
#         70 to 79: Print 'C'
#
#         60 to 69: Print 'D'
#
#         Below 60: Print 'F'
#
# Hint: Use a series of if-elif-else statements to handle the different grade ranges effectively.

# %% [markdown]
# Q9: Create a Python program that prints all numbers from 1 to 100 that are divisible by both 3 and 5.
#
#     Use a loop to iterate through the numbers.
#
#     Print each number that satisfies the condition.
#
# Hint: Use the modulus operator (%) to check for divisibility.

# %% [markdown]
# Q10: Create a Python program that calculates the factorial of a number entered by the user.
#
#     Prompt the user to enter a positive integer.
#
#     Use a while loop to calculate the factorial of the number.
#
#     Print the result in a clear format.
#
# Hint: Remember that the factorial of 0 is 1.

# %% [markdown]
# Q11: Create a Python program that prints all even numbers between 1 and 20.
#
#     Use a for loop to iterate through the numbers.
#
#     Print only the even numbers in this range.
#
# Hint: Use the modulus operator (%) to check if a number is even.

# %% [markdown]
# Q12: Write a program that prints numbers from 1 to 10 and stops the loop if the number is 5.

# %% [markdown]
# Q13: Create a Python program that prints numbers from 1 to 10 but stops the loop if the number is 5.
#
#     Use a for loop to iterate through the numbers.
#
#     Use a break statement to stop the loop when the number 5 is reached.
#
# Hint: The break keyword immediately stops the loop when a certain condition is met.

# %% [markdown]
# Q14: Create a Python program that generates a multiplication table for the numbers 1 through 3.
#
#     Use a nested loop to calculate the products.
#
#     Print the results in a table format for better readability.
#
# Hint: Use two for loops – the outer loop for the rows and the inner loop for the columns.

# %% [markdown]
# Q15: Create a Python function that takes a student's name and age as input, and then prints a personalized message.
#
#     Define a function that accepts two parameters: name and age.
#
#     Use the parameters to construct a friendly message.
#
#     Call the function with sample values to test it.

# %% [markdown]
# Q16: Create a Python function that calculates the area of a rectangle.
#
#     The function should accept two parameters: length and width.
#
#     If the width is not provided, it should default to 5.
#
#     Print the calculated area.
#
# Hint: Use default parameters to handle the case where only the length is provided.

# %% [markdown]
# Q17: Create a Python program that defines a list with 5 numbers.
#
#     Print the second item of the list.
#
#     Ensure the output clearly shows the selected item.
#
# Hint: Remember that list indexing in Python starts at 0, so the second item is at index 1.

# %% [markdown]
# Q18: Use the math module to calculate the square root of 144 and print the result.
